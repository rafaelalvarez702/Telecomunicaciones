# %% [markdown]
# # ETL #

# %%
# Importamos las librerias necesarias
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# Se cargan los archivos a utilizar 
df1= pd.read_csv('01_Internet_Penetracion_100hab.csv')
df2= pd.read_csv('03_Internet_Penetracion_c100ho.csv')
df3= pd.read_csv('02_Internet_Penetracion_100hogyhab.csv')
df4= pd.read_csv('04_Internet_Accesos-por-velocidadbajapro.csv')
df10= pd.read_csv('df1010.csv')
dftv= pd.read_csv('Television año.csv')
dftm= pd.read_csv('Telefonia_movil.csv')
dfinac= pd.read_csv('02_Internet_Penetracion_100hogyhab.csv')
dfitelef=pd.read_csv('ingresosTelefonia_movil.csv')
dfitelv=pd.read_csv('Televisioningresos.csv')
df11= pd.read_csv('dfingresos.csv')

# %%
# Se revisan los datos cargados 
df1.head()
# Out:
#     Año  Trimestre        Provincia Accesos por cada 100 hab
# 0  2022          4     Buenos Aires                    26,72
# 1  2022          4  Capital Federal                    50,35
# 2  2022          4        Catamarca                    16,73
# 3  2022          4            Chaco                    11,66
# 4  2022          4           Chubut                    26,23

# %%
# hacemos info y verificamos el tipo de dato y la precensia de nulos
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Año                       864 non-null    int64
#  1   Trimestre                 864 non-null    int64
#  2   Provincia                 864 non-null    object
#  3   Accesos por cada 100 hab  864 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 27.1+ KB

# %%
df1['Accesos por cada 100 hab'] = df1['Accesos por cada 100 hab'].str.replace(',', '.').astype('float64')

# %%
# Remplazo las ',' por '.' y poder transformar el tipo de dato de las columnas
df1['Accesos por cada 100 hab'] = [x.replace(',' , '.') for x in df1['Accesos por cada 100 hab']]
df1['Accesos por cada 100 hab'] = df1['Accesos por cada 100 hab'].astype('float64')

# %%
# verificamos los cambios
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Año                       864 non-null    int64
#  1   Trimestre                 864 non-null    int64
#  2   Provincia                 864 non-null    object
#  3   Accesos por cada 100 hab  864 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 27.1+ KB

# %%
# Revisamos los datos los datos 
df2.head()
# Out:
#     Año  Trimestre        Provincia Accesos por cada 100 hogares  Unnamed: 4
# 0  2022          4     Buenos Aires                        78,94         NaN  \
# 1  2022          4  Capital Federal                       122,73         NaN
# 2  2022          4        Catamarca                        65,77         NaN
# 3  2022          4            Chaco                        43,62         NaN
# 4  2022          4           Chubut                        85,57         NaN
#
#    Unnamed: 5  Unnamed: 6
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
# verificamos el tipo de dato y la precensia de nulos
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           864 non-null    int64
#  1   Trimestre                     864 non-null    int64
#  2   Provincia                     864 non-null    object
#  3   Accesos por cada 100 hogares  864 non-null    object
#  4   Unnamed: 4                    0 non-null      float64
#  5   Unnamed: 5                    0 non-null      float64
#  6   Unnamed: 6                    0 non-null      float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 47.4+ KB

# %%
# vemos que hay columnas sin datos  las eliminamos y remplazmos las ',' por '.' y poder transformar el tipo de dato de las columnas
df2=df2.drop(['Unnamed: 4','Unnamed: 5','Unnamed: 6'], axis =1)
df2['Accesos por cada 100 hogares'] = [x.replace(',' , '.') for x in df2['Accesos por cada 100 hogares']]
df2['Accesos por cada 100 hogares'] = df2['Accesos por cada 100 hogares'].astype('float64')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           864 non-null    int64
#  1   Trimestre                     864 non-null    int64
#  2   Provincia                     864 non-null    object
#  3   Accesos por cada 100 hogares  864 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 27.1+ KB

# %%
# se decide construir un df conlos dos anteriores 
df_int_penetracion_prov = df1.merge(df2)
df_int_penetracion_prov.head()
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hab
# 0  2022          4     Buenos Aires                     26.72  \
# 1  2022          4  Capital Federal                     50.35
# 2  2022          4        Catamarca                     16.73
# 3  2022          4            Chaco                     11.66
# 4  2022          4           Chubut                     26.23
#
#    Accesos por cada 100 hogares
# 0                         78.94
# 1                        122.73
# 2                         65.77
# 3                         43.62
# 4                         85.57

# %%
# Ordenamos el df por las columnas 'Año', 'Provincia'
df_int_penetracion_prov=df_int_penetracion_prov.sort_values(by = ['Año', 'Provincia'])
df_int_penetracion_prov
# Out:
#       Año  Trimestre         Provincia  Accesos por cada 100 hab
# 768  2014          4      Buenos Aires                     17.01  \
# 792  2014          3      Buenos Aires                     17.26
# 816  2014          2      Buenos Aires                     16.79
# 840  2014          1      Buenos Aires                     16.69
# 769  2014          4   Capital Federal                     43.60
# ..    ...        ...               ...                       ...
# 94   2022          1  Tierra Del Fuego                     29.14
# 23   2022          4           Tucumán                     15.12
# 47   2022          3           Tucumán                     15.14
# 71   2022          2           Tucumán                     14.69
# 95   2022          1           Tucumán                     14.22
#
#      Accesos por cada 100 hogares
# 768                         56.09
# 792                         56.75
# 816                         55.06
# 840                         54.57
# ...

# %%
# revisamos el dataframe
df4.head()
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps
# 0  2022          4     Buenos Aires          28.934               23.347  \
# 1  2022          4  Capital Federal         516.000                5.096
# 2  2022          4        Catamarca          71.000              315.000
# 3  2022          4            Chaco         461.000              771.000
# 4  2022          4           Chubut         109.000                1.614
#
#   + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps
# 0           259.866             281.550              244.555  \
# 1            31.320              64.653               36.336
# 2             2.716               5.028                4.638
# 3            16.067              17.846                6.704
# 4            46.457              31.007               34.728
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps    OTROS      Total
# 0               98.670  3.760.109   97.634  4.794.665
# ...

# %%
# Verificamos tipo de datos y nulos
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año                  864 non-null    int64
#  1   Trimestre            864 non-null    int64
#  2   Provincia            864 non-null    object
#  3   HASTA 512 kbps       864 non-null    float64
#  4   + 512 Kbps - 1 Mbps  864 non-null    float64
#  5   + 1 Mbps - 6 Mbps    864 non-null    object
#  6   + 6 Mbps - 10 Mbps   864 non-null    float64
#  7   + 10 Mbps - 20 Mbps  864 non-null    float64
#  8   + 20 Mbps - 30 Mbps  864 non-null    float64
#  9   + 30 Mbps            864 non-null    object
#  10  OTROS                858 non-null    float64
#  11  Total                864 non-null    object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 81.1+ KB

# %%
# Remplazamos los '.' y convertimos las columnas
columns_to_replace = ['+ 1 Mbps - 6 Mbps', '+ 30 Mbps', 'Total']
df4 = df4.copy()
df4[columns_to_replace] = df4[columns_to_replace].applymap(lambda x: x.replace('.' , ''))

# %%
# verificamos el cambio 
df4 = df4.astype({'+ 1 Mbps - 6 Mbps':'float' , '+ 30 Mbps':'float', 'Total': 'float'})
df4.dtypes
# Out:
# Año                      int64
# Trimestre                int64
# Provincia               object
# HASTA 512 kbps         float64
# + 512 Kbps - 1 Mbps    float64
# + 1 Mbps - 6 Mbps      float64
# + 6 Mbps - 10 Mbps     float64
# + 10 Mbps - 20 Mbps    float64
# + 20 Mbps - 30 Mbps    float64
# + 30 Mbps              float64
# OTROS                  float64
# Total                  float64
# dtype: object

# %%
# Revisamos los datos nulos de la columna otros
df4[df4['OTROS'].isnull()]
# Out:
#       Año  Trimestre         Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps
# 337  2019          2   Capital Federal            74.0                1.027  \
# 347  2019          2          La Rioja             9.0               11.000
# 348  2019          2           Mendoza            20.0                2.522
# 355  2019          2        Santa Cruz            25.0               84.000
# 358  2019          2  Tierra Del Fuego             6.0              123.000
# 359  2019          2           Tucumán            16.0              157.000
#
#      + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps
# 337           281370.0             124.087              239.691  \
# 347            39819.0               4.297                4.857
# 348           205165.0               2.971               10.092
# 355            24861.0               3.806                1.202
# 358            41824.0               4.241                1.573
# ...

# %%
# Se decide remplazar los nulos con '0 ' ya que hay mas datos en las otras columnas y se puede asumir son valores faltantes
df4['OTROS'].fillna(0, inplace=True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año                  864 non-null    int64
#  1   Trimestre            864 non-null    int64
#  2   Provincia            864 non-null    object
#  3   HASTA 512 kbps       864 non-null    float64
#  4   + 512 Kbps - 1 Mbps  864 non-null    float64
#  5   + 1 Mbps - 6 Mbps    864 non-null    float64
#  6   + 6 Mbps - 10 Mbps   864 non-null    float64
#  7   + 10 Mbps - 20 Mbps  864 non-null    float64
#  8   + 20 Mbps - 30 Mbps  864 non-null    float64
#  9   + 30 Mbps            864 non-null    float64
#  10  OTROS                864 non-null    float64
#  11  Total                864 non-null    float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 81.1+ KB

# %%
df4.head()
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps
# 0  2022          4     Buenos Aires          28.934               23.347  \
# 1  2022          4  Capital Federal         516.000                5.096
# 2  2022          4        Catamarca          71.000              315.000
# 3  2022          4            Chaco         461.000              771.000
# 4  2022          4           Chubut         109.000                1.614
#
#    + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps
# 0           259866.0             281.550              244.555  \
# 1            31320.0              64.653               36.336
# 2             2716.0               5.028                4.638
# 3            16067.0              17.846                6.704
# 4            46457.0              31.007               34.728
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps    OTROS      Total
# 0               98.670  3760109.0   97.634  4794665.0
# ...

# %%
df10=pd.read_csv('df1010.csv')

# %%
#revisamos el dataframe
df10
# Out:
#       Año  Trimestre            Provincia      ADSL  Cablemodem  Fibra óptica
# 0    2022          4         Buenos Aires  325908.0   2767247.0     1499149.0  \
# 1    2022          4      Capital Federal  138753.0   1238196.0      138548.0
# 2    2022          4            Catamarca    8952.0     10998.0       47337.0
# 3    2022          4                Chaco   24582.0     61265.0       47285.0
# 4    2022          4               Chubut   45450.0     73923.0        9815.0
# ..    ...        ...                  ...       ...         ...           ...
# 859  2014          1           Santa Cruz   18927.0       100.0         381.0
# 860  2014          1             Santa Fe  322662.0    174296.0        3059.0
# 861  2014          1  Santiago Del Estero   32567.0      3598.0          19.0
# 862  2014          1     Tierra Del Fuego   21618.0      2837.0         648.0
# 863  2014          1              Tucumán  129717.0        83.0         121.0
#
# ...

# %%
# Verificamos tipo de datos y nulos
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           864 non-null    int64
#  1   Trimestre     864 non-null    int64
#  2   Provincia     864 non-null    object
#  3   ADSL          864 non-null    float64
#  4   Cablemodem    864 non-null    float64
#  5   Fibra óptica  864 non-null    float64
#  6   Wireless      864 non-null    float64
#  7   Otros         864 non-null    float64
#  8   Total         864 non-null    float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 60.9+ KB

# %%
#secrea un df con los 'df4' y 'df5'
df_int_acve_pro = df10.merge(df4, left_index=True, right_index=True)
df_int_acve_pro
# Out:
#      Año_x  Trimestre_x          Provincia_x      ADSL  Cablemodem
# 0     2022            4         Buenos Aires  325908.0   2767247.0  \
# 1     2022            4      Capital Federal  138753.0   1238196.0
# 2     2022            4            Catamarca    8952.0     10998.0
# 3     2022            4                Chaco   24582.0     61265.0
# 4     2022            4               Chubut   45450.0     73923.0
# ..     ...          ...                  ...       ...         ...
# 859   2014            1           Santa Cruz   18927.0       100.0
# 860   2014            1             Santa Fe  322662.0    174296.0
# 861   2014            1  Santiago Del Estero   32567.0      3598.0
# 862   2014            1     Tierra Del Fuego   21618.0      2837.0
# 863   2014            1              Tucumán  129717.0        83.0
#
#      Fibra óptica  Wireless    Otros    Total_x  Año_y  ...
# 0       1499149.0  129910.0  72451.0  4794665.0   2022  ...  \
# ...

# %%
# Eliminamos las columnas duplicadas en el merge y sustituimos los nombres de otras
df_int_acve_pro=df_int_acve_pro.drop(['Año_y','Trimestre_y','Provincia_y'], axis =1)
df_int_acve_pro.rename(columns={'Año_x':'Año', 'Trimestre_x':'Trimestre','Provincia_x':'Provincia' }, inplace=True)
df_int_acve_pro.head()
# Out:
#     Año  Trimestre        Provincia      ADSL  Cablemodem  Fibra óptica
# 0  2022          4     Buenos Aires  325908.0   2767247.0     1499149.0  \
# 1  2022          4  Capital Federal  138753.0   1238196.0      138548.0
# 2  2022          4        Catamarca    8952.0     10998.0       47337.0
# 3  2022          4            Chaco   24582.0     61265.0       47285.0
# 4  2022          4           Chubut   45450.0     73923.0        9815.0
#
#    Wireless    Otros    Total_x  HASTA 512 kbps  + 512 Kbps - 1 Mbps
# 0  129910.0  72451.0  4794665.0          28.934               23.347  \
# 1    4603.0  31826.0  1551926.0         516.000                5.096
# 2    1379.0   2243.0    70909.0          71.000              315.000
# 3    7957.0   2574.0   143663.0         461.000              771.000
# 4   30721.0   8850.0   168759.0         109.000                1.614
#
#    + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps
# ...

# %%
# verificamos los cambios en el tipo de dato
df_int_acve_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año                  864 non-null    int64
#  1   Trimestre            864 non-null    int64
#  2   Provincia            864 non-null    object
#  3   ADSL                 864 non-null    float64
#  4   Cablemodem           864 non-null    float64
#  5   Fibra óptica         864 non-null    float64
#  6   Wireless             864 non-null    float64
#  7   Otros                864 non-null    float64
#  8   Total_x              864 non-null    float64
#  9   HASTA 512 kbps       864 non-null    float64
#  10  + 512 Kbps - 1 Mbps  864 non-null    float64
#  11  + 1 Mbps - 6 Mbps    864 non-null    float64
#  12  + 6 Mbps - 10 Mbps   864 non-null    float64
#  13  + 10 Mbps - 20 Mbps  864 non-null    float64
#  14  + 20 Mbps - 30 Mbps  864 non-null    float64
# ...

# %%
# verificamos los datos
dftv
# Out:
#        Año  Trimestre Accesos TV por suscripción por cada 100 hab
# 0   2022.0        4.0                                       16,55  \
# 1   2022.0        3.0                                       16,56
# 2   2022.0        2.0                                       16,55
# 3   2022.0        1.0                                       16,41
# 4   2021.0        4.0                                       16,52
# 5   2021.0        3.0                                       16,73
# 6   2021.0        2.0                                       16,02
# 7   2021.0        1.0                                       16,09
# 8   2020.0        4.0                                       16,10
# 9   2020.0        3.0                                       16,13
# 10  2020.0        2.0                                       15,93
# 11  2020.0        1.0                                       15,97
# 12  2019.0        4.0                                       16,17
# ...

# %%
# vemos los tipos de datos y nulos
dftv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Año                                              36 non-null     float64
#  1   Trimestre                                        36 non-null     float64
#  2   Accesos TV por suscripción por cada 100 hab      37 non-null     object
#  3   Accesos TV satelital por cada 100 hab            37 non-null     object
#  4   Accesos TV por suscripción por cada 100 hogares  37 non-null     object
#  5   Accesos TV satelital por cada 100 hogares        37 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 1.9+ KB

# %%
# Observamos que la fila '36' faltan en 'Año' y ' Trimestre', pero despues de revisar en detalle, se decide eliminar la fila 
# por que las filas restantes tienen informacion completa para el analis desde 2104 a 2022 
dftv= dftv.dropna()

# %%
# verificamos
dftv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Año                                              36 non-null     float64
#  1   Trimestre                                        36 non-null     float64
#  2   Accesos TV por suscripción por cada 100 hab      36 non-null     object
#  3   Accesos TV satelital por cada 100 hab            36 non-null     object
#  4   Accesos TV por suscripción por cada 100 hogares  36 non-null     object
#  5   Accesos TV satelital por cada 100 hogares        36 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 2.0+ KB

# %%
# reemplazamos la ',' por '.' 
columns_to_replace = ['Accesos TV por suscripción por cada 100 hab', 'Accesos TV por suscripción por cada 100 hogares', 
                      'Accesos TV satelital por cada 100 hab','Accesos TV satelital por cada 100 hogares']
dftv = dftv.copy()
dftv[columns_to_replace] = dftv[columns_to_replace].applymap(lambda x: x.replace(',' , '.'))

# %%
# cambiamos los tipos de datos
dftv = dftv.astype({'Año': 'int64', 'Trimestre': 'int64', 'Accesos TV por suscripción por cada 100 hab':'float',
                    'Accesos TV por suscripción por cada 100 hogares': 'float', 'Accesos TV satelital por cada 100 hab': 'float', 
                    'Accesos TV satelital por cada 100 hogares': 'float'})
dftv.dtypes
# Out:
# Año                                                  int64
# Trimestre                                            int64
# Accesos TV por suscripción por cada 100 hab        float64
# Accesos TV satelital por cada 100 hab              float64
# Accesos TV por suscripción por cada 100 hogares    float64
# Accesos TV satelital por cada 100 hogares          float64
# dtype: object

# %%
# vemos los datos
dftm.head()
# Out:
#     Año  Trimestre  Accesos por cada 100 hab        Periodo
# 0  2013          1                    15.437   Ene-Mar 2013
# 1  2013          2                    15.600   Abr-Jun 2013
# 2  2013          3                    15.859  Jul-Sept 2013
# 3  2013          4                    15.937   Oct-Dic 2013
# 4  2014          1                    14.807   Ene-Mar 2014

# %%
# verificamos los tipos de datos y nulos
dftm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Año                       40 non-null     int64
#  1   Trimestre                 40 non-null     int64
#  2   Accesos por cada 100 hab  40 non-null     float64
#  3   Periodo                   40 non-null     object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.4+ KB

# %%
# para mantener la relacion con los otros df decidimos eliminar las filas '0,1,2,3' y trabajar con un espacio muestral de '2014 a 2022'
dftm.drop([0, 1, 2, 3], axis=0, inplace=True)
dftm.reset_index(drop=True, inplace=True)

# %%
# eliminamos la columna 'Periodo'
dftm=dftm.drop(['Periodo'], axis =1)

# %%
# renombramos la columna 
dftm.rename(columns={'Accesos por cada 100 hab':'Accesos movil 100 hab' }, inplace=True)

# %%
# verificamos los cambios
dftm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Año                    36 non-null     int64
#  1   Trimestre              36 non-null     int64
#  2   Accesos movil 100 hab  36 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 992.0 bytes

# %%
# vemos los datos
dfinac.head()
# Out:
#     Año  Trimestre Accesos por cada 100 hogares Accesos por cada 100 hab
# 0  2022          4                        77,21                    24,15  \
# 1  2022          3                        76,64                    23,95
# 2  2022          2                        75,97                    23,72
# 3  2022          1                        73,88                    23,05
# 4  2021          4                        73,18                    22,81
#
#          Periodo
# 0   Oct-Dic 2022
# 1  Jul-Sept 2022
# 2   Abr-Jun 2022
# 3   Ene-Mar 2022
# 4   Oct-Dic 2021

# %%
# verificamos el tipo de dato y nulos
dfinac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           36 non-null     int64
#  1   Trimestre                     36 non-null     int64
#  2   Accesos por cada 100 hogares  36 non-null     object
#  3   Accesos por cada 100 hab      36 non-null     object
#  4   Periodo                       36 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
# reemplazamos la ',' por '.'
dfinac = dfinac.copy()
columns_to_replace = ['Accesos por cada 100 hogares', 'Accesos por cada 100 hab']
dfinac[columns_to_replace] = dfinac[columns_to_replace].applymap(lambda x: x.replace(',' , '.'))

# %%
# cambiamos el tipo de dato
dfinac = dfinac.astype({'Accesos por cada 100 hogares':'float', 'Accesos por cada 100 hab': 'float'})

# %%
# eliminamos la columna 'periodo'
dfinac=dfinac.drop(['Periodo'], axis =1)

# %%
#verificamos los cambios
dfinac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           36 non-null     int64
#  1   Trimestre                     36 non-null     int64
#  2   Accesos por cada 100 hogares  36 non-null     float64
#  3   Accesos por cada 100 hab      36 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.2 KB

# %%
# renombramos las columnas
dfinac.rename(columns={'Accesos por cada 100 hogares':'Accesos internet 100 hogares', 'Accesos por cada 100 hab':'Accesos internet 100 hab' }, inplace=True)

# %%
# creamos un df para facilitar su uso
df_anual_int_tv_mv=dfinac.merge(dftv)
df_anual_int_tv_mv = df_anual_int_tv_mv.merge(dftm)
df_anual_int_tv_mv.head()
# Out:
#     Año  Trimestre  Accesos internet 100 hogares  Accesos internet 100 hab
# 0  2022          4                         77.21                     24.15  \
# 1  2022          3                         76.64                     23.95
# 2  2022          2                         75.97                     23.72
# 3  2022          1                         73.88                     23.05
# 4  2021          4                         73.18                     22.81
#
#    Accesos TV por suscripción por cada 100 hab
# 0                                        16.55  \
# 1                                        16.56
# 2                                        16.55
# 3                                        16.41
# 4                                        16.52
#
#    Accesos TV satelital por cada 100 hab
# 0                                   3.96  \
# 1                                   4.46
# 2                                   4.47
# 3                                   4.45
# ...

# %%
# vemos los datos
dfitelef.head()
# Out:
#     Año  Trimestre Ingresos (miles de $)        Periodo
# 0  2013          1          $ 13.135.235   Ene-Mar 2013
# 1  2013          2          $ 13.970.806   Abr-Jun 2013
# 2  2013          3          $ 15.235.659  Jul-Sept 2013
# 3  2013          4          $ 16.218.846   Oct-Dic 2013
# 4  2014          1          $ 15.938.353   Ene-Mar 2013

# %%
# vemos los datos
dfitelv.head()
# Out:
#     Año  Trimestre Ingresos TV por suscripción  (miles de $)
# 0  2022          4                             62.432.903,15  \
# 1  2022          3                             52.399.891,49
# 2  2022          2                             46.322.065,49
# 3  2022          1                             42.113.438,81
# 4  2021          4                             38.273.391,80
#
#   Ingresos TV satelital (miles de $)
# 0                      29.721.126,94
# 1                      27.073.190,89
# 2                      23.559.484,83
# 3                      21.268.086,24
# 4                      18.038.065,44

# %%
# vemos los datos
df11.head()
# Out:
#     Año  Trimestre  Ingresos (miles de pesos)
# 0  2022          4                72443482.99
# 1  2022          3                64086784.33
# 2  2022          2                60419500.62
# 3  2022          1                55219313.01
# 4  2021          4                45467887.17

# %%
# configuramos panda para no ver notacion cientifica
pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))

# %%
df11.head()
# Out:
#     Año  Trimestre  Ingresos (miles de pesos)
# 0  2022          4                72443482.99
# 1  2022          3                64086784.33
# 2  2022          2                60419500.62
# 3  2022          1                55219313.01
# 4  2021          4                45467887.17

# %%
# creamos un df ingresos
df_ingresos = df11.merge(dfitelef)
df_ingresos = df_ingresos.merge(dfitelv)

# %%
df_ingresos.head()
# Out:
#     Año  Trimestre  Ingresos (miles de pesos) Ingresos (miles de $)
# 0  2022          4                72443482.99         $ 204.796.575  \
# 1  2022          3                64086784.33         $ 180.356.862
# 2  2022          2                60419500.62         $ 153.032.313
# 3  2022          1                55219313.01         $ 130.454.676
# 4  2021          4                45467887.17         $ 127.389.786
#
#          Periodo Ingresos TV por suscripción  (miles de $)
# 0   Oct-Dic 2022                             62.432.903,15  \
# 1  Jul-Sept 2022                             52.399.891,49
# 2   Abr-Jun 2022                             46.322.065,49
# 3   Ene-Mar 2022                             42.113.438,81
# 4   Oct-Dic 2021                             38.273.391,80
#
#   Ingresos TV satelital (miles de $)
# 0                      29.721.126,94
# 1                      27.073.190,89
# 2                      23.559.484,83
# 3                      21.268.086,24
# ...

# %%
# eliminamos la columna periodo
df_ingresos = df_ingresos.drop(['Periodo'],axis=1)

# %%
# verificamos el cambio 
df_ingresos.head()
# Out:
#     Año  Trimestre  Ingresos (miles de pesos) Ingresos (miles de $)
# 0  2022          4                72443482.99         $ 204.796.575  \
# 1  2022          3                64086784.33         $ 180.356.862
# 2  2022          2                60419500.62         $ 153.032.313
# 3  2022          1                55219313.01         $ 130.454.676
# 4  2021          4                45467887.17         $ 127.389.786
#
#   Ingresos TV por suscripción  (miles de $) Ingresos TV satelital (miles de $)
# 0                             62.432.903,15                      29.721.126,94
# 1                             52.399.891,49                      27.073.190,89
# 2                             46.322.065,49                      23.559.484,83
# 3                             42.113.438,81                      21.268.086,24
# 4                             38.273.391,80                      18.038.065,44

# %%
# se elimina el simbolo '$' 
columns_to_replace = ['Ingresos (miles de $)']
df_ingresos = df_ingresos.copy()
df_ingresos[columns_to_replace] = df_ingresos[columns_to_replace].applymap(lambda x: x.replace('$' , ''))

# %%
# se elimina el '.' 
columns_to_replace = [ 'Ingresos (miles de $)', 'Ingresos TV por suscripción  (miles de $)',
                                 'Ingresos TV satelital (miles de $)']
df_ingresos = df_ingresos.copy()
df_ingresos[columns_to_replace] = df_ingresos[columns_to_replace].applymap(lambda x: x.replace('.' , ''))

# %%
# se reemplaza la ',' por '.'
columns_to_replace = [ 'Ingresos (miles de $)', 'Ingresos TV por suscripción  (miles de $)',
                                 'Ingresos TV satelital (miles de $)']
df_ingresos = df_ingresos.copy()
df_ingresos[columns_to_replace] = df_ingresos[columns_to_replace].applymap(lambda x: x.replace(',' , '.'))

# %%
# modificamos el tipo de dato
df_ingresos = df_ingresos.astype({'Ingresos (miles de pesos)': 'float64','Ingresos (miles de $)': 'float64', 'Ingresos TV por suscripción  (miles de $)': 'float64',
                                 'Ingresos TV satelital (miles de $)':'float64'})

# %%
# verificamos los cambios
df_ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Año                                        36 non-null     int64
#  1   Trimestre                                  36 non-null     int64
#  2   Ingresos (miles de pesos)                  36 non-null     float64
#  3   Ingresos (miles de $)                      36 non-null     float64
#  4   Ingresos TV por suscripción  (miles de $)  36 non-null     float64
#  5   Ingresos TV satelital (miles de $)         36 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 1.8 KB

# %%
# guardamos los df en csv para facilitar su uso
guardar = 'df_int_penetracion_prov.csv'
df_int_penetracion_prov.to_csv(guardar, index=False, encoding='utf-8')

guardar = 'df_int_acve_pro.csv'
df_int_acve_pro.to_csv(guardar, index=False, encoding='utf-8')

guardar = 'df_anual_int_tv_mv.csv'
df_anual_int_tv_mv.to_csv(guardar, index=False, encoding='utf-8')

guardar = 'df_ingresos.csv'
df_ingresos.to_csv(guardar, index=False, encoding='utf-8')
